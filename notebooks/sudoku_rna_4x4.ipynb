# %% [markdown]
# # Sudoku 4x4 com RNA Multicamadas
#
# Este notebook apresenta uma solução comentada em Markdown para o trabalho de IA.

# %% [markdown]
# ## Ideia geral
#
# A RNA multicamadas é usada para reconhecer se um tabuleiro completo é válido ou inválido. A geração da solução final usa backtracking, pois Sudoku é um problema de raciocínio lógico e restrições.

# %%
# Para executar no notebook, copie o conteúdo de src/sudoku_rna_4x4.py
# ou importe o arquivo após configurar o caminho do projeto.

# %% [markdown]
# ## Discussão sobre generalização para NxN
#
# Ao generalizar de 4x4 para NxN, a entrada one-hot cresce para N³ atributos. Além disso, o espaço de busca cresce exponencialmente, tornando inviável testar amostras aleatórias sem raciocínio lógico ou heurísticas.
